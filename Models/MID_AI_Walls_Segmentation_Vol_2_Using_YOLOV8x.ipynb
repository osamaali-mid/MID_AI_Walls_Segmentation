# %%
# !nvidia-smi
# Out:
# Fri Aug 23 17:21:21 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0              44W / 400W |      2MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Setup complete ✅ (12 CPUs, 83.5 GB RAM, 33.7/201.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd {HOME}
# !yolo task=segment mode=predict model=yolov8x-seg.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=true
# Out:
# /content
# ...
# 100% 137M/137M [00:01<00:00, 132MB/s]
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# YOLOv8x-seg summary (fused): 295 layers, 71797696 parameters, 0 gradients, 344.1 GFLOPs
#
# ...
# 100% 104k/104k [00:00<00:00, 113MB/s]
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 1 backpack, 310.7ms
# Speed: 15.1ms preprocess, 310.7ms inference, 790.0ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
Image(filename='runs/segment/predict/dog.jpeg', height=600)
# Out:
# /content

# %%
model = YOLO(f'{HOME}/yolov8x-seg.pt')
results = model.predict(source='https://media.roboflow.com/notebooks/examples/dog.jpeg', conf=0.25)
# Out:
# Found https://media.roboflow.com/notebooks/examples/dog.jpeg locally at dog.jpeg
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 1 backpack, 319.5ms
# Speed: 5.9ms preprocess, 319.5ms inference, 645.4ms postprocess per image at shape (1, 3, 640, 384)

# %%
results[0].boxes.xyxy
# Out:
# tensor([[0.0000e+00, 3.5878e+02, 6.4402e+02, 1.2746e+03],
#         [6.9541e+01, 2.4982e+02, 6.3971e+02, 9.2349e+02],
#         [7.4896e-01, 6.6510e+02, 4.4171e+02, 1.2796e+03],
#         [6.2699e+02, 7.3472e+02, 6.9833e+02, 7.8746e+02]], device='cuda:0')

# %%
results[0].boxes.conf
# Out:
# tensor([0.9164, 0.8988, 0.8810, 0.5395], device='cuda:0')

# %%
results[0].boxes.cls
# Out:
# tensor([ 0., 16., 24.,  2.], device='cuda:0')

# %%
results[0].masks.xyn
# Out:
# [array([[    0.55278,     0.52031],
#         [       0.55,     0.52188],
#         [    0.53611,     0.52188],
#         ...,
#         [      0.575,     0.52188],
#         [    0.56944,     0.52188],
#         [    0.56667,     0.52031]], dtype=float32),
#  array([[    0.44444,         0.2],
#         [    0.44167,     0.20156],
#         [    0.43056,     0.20156],
#         [    0.42778,     0.20312],
#         [      0.425,     0.20312],
#         [    0.42222,     0.20469],
#         [    0.41944,     0.20469],
#         [    0.41667,     0.20625],
#         [    0.41389,     0.20625],
#         [    0.41111,     0.20781],
#         [    0.40833,     0.20781],
#         [    0.40278,     0.21094],
#         [        0.4,     0.21094],
#         [    0.39722,      0.2125],
#         [    0.39444,      0.2125],
#         [    0.38056,     0.22031],
#         [    0.37778,     0.22031],
#         [    0.37778,     0.22187],
#         [    0.37222,       0.225],
# ...

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow --quiet

from roboflow import Roboflow
rf = Roboflow(api_key="Ty6H3vhtJnhjj9X8aCff")
project = rf.workspace("ai-flooring-model-mid").project("walls-segmentation-detection")
dataset = project.version(9).download("yolov8")
# Out:
# /content/datasets
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.5 MB/s eta 0:00:00
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov8 in progress : 85.0%
# Version export complete for yolov8 format
# ...
# Extracting Dataset Version Zip to Walls-Segmentation-(Detection)-9 in yolov8:: 100%|██████████| 1419/1419 [00:00<00:00, 7868.18it/s]

# %%
# %cd {HOME}

# !yolo task=segment mode=train model=yolov8x-seg.pt data="{dataset.location}/data.yaml" epochs=100 imgsz=640
# Out:
# /content
# New https://pypi.org/project/ultralytics/8.2.81 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
# !ls {HOME}/runs/segment/train/
# Out:
# args.yaml					    labels.jpg	      train_batch2.jpg
# BoxF1_curve.png					    MaskF1_curve.png  train_batch3690.jpg
# BoxP_curve.png					    MaskP_curve.png   train_batch3691.jpg
# BoxPR_curve.png					    MaskPR_curve.png  train_batch3692.jpg
# BoxR_curve.png					    MaskR_curve.png   val_batch0_labels.jpg
# confusion_matrix_normalized.png			    results.csv       val_batch0_pred.jpg
# confusion_matrix.png				    results.png       val_batch1_labels.jpg
# events.out.tfevents.1724434053.a5fa521e6a88.2891.0  train_batch0.jpg  val_batch1_pred.jpg
# labels_correlogram.jpg				    train_batch1.jpg  weights

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/segment/train/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/segment/train/results.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/segment/train/val_batch0_pred.jpg', width=600)
# Out:
# /content

# %%
# !yolo task=segment mode=val model=/content/runs/segment/train/weights/best.pt data="/content/datasets/Walls-Segmentation-(Detection)-9/data.yaml"
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# YOLOv8x-seg summary (fused): 295 layers, 71721619 parameters, 0 gradients, 343.7 GFLOPs
# val: Scanning /content/datasets/Walls-Segmentation-(Detection)-9/valid/labels.cache... 36 images, 0 backgrounds, 0 corrupt: 100% 36/36 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 3/3 [00:04<00:00,  1.34s/it]
#                    all         36        252      0.757      0.803      0.847      0.711      0.788      0.708      0.795      0.428
# Speed: 4.7ms preprocess, 38.6ms inference, 0.0ms loss, 21.8ms postprocess per image
# Results saved to runs/segment/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
project.version(dataset.version).deploy(model_type="yolov8-seg", model_path=f"{HOME}/runs/segment/train/")
# Out:
# View the status of your deployment at: https://app.roboflow.com/ai-flooring-model-mid/walls-segmentation-detection/9
